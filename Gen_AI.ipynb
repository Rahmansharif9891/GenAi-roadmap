# %% [markdown]
# <a href="https://colab.research.google.com/github/Rahmansharif9891/GenAi-roadmap/blob/main/Gen_AI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("salam")
# Out:
# salam

# %%
name = "Aklaqur rahman"
age = 25
height = 1.34

print(age)
print(name)
print(height)

print(type(age))
print(type(name))
print(type(height))
# Out:
# 25
# Aklaqur rahman
# 1.34
# <class 'int'>
# <class 'str'>
# <class 'float'>

# %%
a = 8
b = 3
print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a%b)
print(a^b)
print(a//b)
print(a**b)

# R.Operators
print("[R.Operators]")
print(a ==b)
print(a>=b)
print(a>b)
print(a<b)
print(a<=b)
print(a!=b)




n1 = int(input("enter the number :"))
n2 = int(input("enter the number :"))
print(n1 +n2)
print(n1- n2)
print(n1 *n2)
print(n1 **n2)
print(n1 /n2)
print(n1 //n2)
print(n1 %n2)
print(n1^ n2)
# Out:
# 11
# 5
# 24
# 2.6666666666666665
# 2
# 11
# 2
# 512
# [R.Operators]
# False
# True
# True
# False
# False
# True
# enter the number :9
# enter the number :2
# 11
# 7
# 18
# 81
# 4.5
# 4
# 1
# 11

# %%
int = 25
float = 23.4
str = "the car is slow"
bool = True & False
list = [1,2,3] # collection of data  mutable
Tuple = (1,2,3,4,5) # immutable
dict = {"name" : "sreelkant", "age":18} # save data in pair
set = {1,2,3,4,5,6} # collection contains the unique values

print(int)
print(float)
print(str)
print()
# Out:
# 25

# %%
for i in range(5):
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
#for i in range(5):
  #print(i)

i = 3
while i <6: #till the condition is true the loop runs
  print(i)
  i+=1 # every time ADD 1+
# Out:
# 0
# 1
# 2
# 3
# 4
# 3
# 4
# 5

# %%
# list [], mutable
age = [11,13,15,17]
print(age[-1])

age.append(19)  # for add value
print(age)
age.remove(19)
print(age)
# Out:
# 17
# [11, 13, 15, 17, 19]
# [11, 13, 15, 17]

# %%
# dict {keys : values}

std = { "name" : "akhlaque", "age" :25, "marks" : 87}
print(std)
print(std["name"])
print(std["age"])
print(std["marks"])
print(std.values())
print(std.keys)
print(std.keys())
# Out:
# {'name': 'akhlaque', 'age': 25, 'marks': 87}
# akhlaque
# 25
# 87
# dict_values(['akhlaque', 25, 87])
# <built-in method keys of dict object at 0x7cba776905c0>
# dict_keys(['name', 'age', 'marks'])

# %%
# func
def sum_number(a, b):
  return(a+b)  # answer = (a+b)
               # return answer

result = sum_number(10,20)
print(result)
# Out:
# 30
